# %% [markdown]
# # Load 2002 NASCAR rankings

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ### Import 2002 NASCAR rankings

# %%
nsc_2002_raw_pth = "../../data/nascar/nascar_2002_all_std.csv"
nsc_2002_raw = pd.read_csv(filepath_or_buffer = nsc_2002_raw_pth, delimiter = ",")

# %%
nsc_2002_raw.head()
# Out:
#    rank pls_min_mv           driver  points  back  starts  pole  win  top_5  \
# 0     1         --      Ward Burton     180     0       1     1    1      1
# 1     2         --   Elliott Sadler     170   -10       1     0    0      1
# 2     3         --  Geoffrey Bodine     165   -15       1     0    0      1
# 3     4         --       Kurt Busch     165   -15       1     1    0      1
# 4     5         --  Michael Waltrip     160   -20       1     0    0      1
#
#    top_10    winnings  year  race_num
# 0       1  $1,409,017  2002         1
# 1       1    $977,324  2002         1
# 2       1    $696,328  2002         1
# 3       1    $552,028  2002         1
# 4       1    $462,043  2002         1

# %% [markdown]
# ### Get rankings for the first race

# %%
nsc_2002_rac_1 = nsc_2002_raw[nsc_2002_raw['race_num'] == 1]
nsc_2002_rac_1.head()
# Out:
#    rank pls_min_mv           driver  points  back  starts  pole  win  top_5  \
# 0     1         --      Ward Burton     180     0       1     1    1      1
# 1     2         --   Elliott Sadler     170   -10       1     0    0      1
# 2     3         --  Geoffrey Bodine     165   -15       1     0    0      1
# 3     4         --       Kurt Busch     165   -15       1     1    0      1
# 4     5         --  Michael Waltrip     160   -20       1     0    0      1
#
#    top_10    winnings  year  race_num
# 0       1  $1,409,017  2002         1
# 1       1    $977,324  2002         1
# 2       1    $696,328  2002         1
# 3       1    $552,028  2002         1
# 4       1    $462,043  2002         1
